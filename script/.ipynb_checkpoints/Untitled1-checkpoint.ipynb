# %%
import pandas as pd
import requests
import io
from bs4 import BeautifulSoup, NavigableString, Tag
from PIL import Image

# %%
# import existing excel file
plant_detail_df = pd.read_excel('../data/Garden_Plant.xlsx')

# %%
# set the header
plant_detail_df.columns = plant_detail_df.iloc[0]
plant_detail_df = plant_detail_df[1:]

# %%
# drop rows with no value
plant_detail_df = plant_detail_df.loc[~plant_detail_df['Name'].isna()]

# %%
# split the name column to name and variety
plant_detail_df[['plant_name', 'plant_variety']] = plant_detail_df['Name'].str.split(r'\n', expand = True)
plant_detail_df[['genus', 'species', 'subsp/var']] = plant_detail_df['Latin'].str.split(n = 2, expand = True)

# %%
# copy additional columns
plant_detail_df['seed_company'] = plant_detail_df['Company'].str.replace('\n', ' ')

# %%
plant_detail_df.reset_index(drop = True, inplace = True)

# %%
zip(plant_df['genus'], plant_df['species'], plant_df['subsp/var'])

# %%
' '.join(plant_df[['genus', 'species', 'subsp/var']])
# Out:
# 'genus species subsp/var'

# %% [markdown]
# ## def Function

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
def get_url(search_kw, company)

    if company == "Johnny's Seed":
        url = f'https://www.johnnyseeds.com/search/?q={search_kw}&search-button=&lang=en_US'
        
        reqs = requests.get(link)
        soup = BeautifulSoup(reqs.text, 'html.parser')
        
        for x in soup.findAll('div', attrs = {'class': 'tile-name product-name'}):
            x.text.strip()
            
    elif company == "Baker Creek":
        url = f'https://www.rareseeds.com/catalogsearch/result/?q={search_kw}'
        
        reqs = requests.get(link)
        soup = BeautifulSoup(reqs.text, 'html.parser')
        
        for x in soup.findAll('div', attrs = {'class' : 'grid--item grid--item_product'}):
            x.find('span', attrs = {'class' : 'product--name'}).text.strip().split('\n')[0]
        
    elif company == "Botanical Interest":
        url = f'https://www.botanicalinterests.com/search?q={search_kw}&options%5Bprefix%5D=last'
        
        reqs = requests.get(link)
        soup = BeautifulSoup(reqs.text, 'html.parser')
        
        for x in soup.findAll('div', attrs = {'class' : 'card__content'}):
            x.find('a').text.strip()

# %%
def scrapping(plant, company, link):
    
    reqs = requests.get(link)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    
    values = {}
    values.update({'plant_name' : plant,
                   'seed_company' : company})

    if company == "Johnny's Seed":
        try:   
            info = soup.findAll("dd", attrs = {'class' : "c-facts__definition"})
            for i in info:
                values.update({i.find_previous_sibling(name = 'dt').find('h3').text.strip() : i.text.strip()})

            detail = soup.find('div', attrs = {'id' : 'tabpanel_2-1'}).findAll('span', attrs = {'style' : ''})
            for i in detail:
                values.update({i.find_previous_sibling(name = 'span').text.strip() : i.text.strip()})
        except:
            pass
            
    elif company == "Baker Creek":
        try:
            values.update({'Latin Name' : soup.findAll('li')[-1].text.strip()})
        except:
            pass
        
    elif company == "Botanical Interest":
        try:
      
            imgs = soup.findAll('li', attrs = {'thumbnail-list__item slider__slide'})
            for i in imgs:
                if 'w_' in i.find('img')['src']:                
                    img_src = i.find('img')['src'].split('?')[0]

                    response = requests.get('http:' + img_src)
                    img = Image.open(io.BytesIO(response.content))
                    tts = pytesseract.image_to_string(img)
                    
                    values.update({'Latin Name' : tts.split('\n')[2:3]})
                    
            info = soup.find('div', attrs = {'class' : 'tab-content'}).findAll('p')
            for i in info:
                values.update({i.text.strip().split(': ')[0] : i.text.strip().split(': ')[1]})
        except:
            pass
            
    elif company == "Swallowtail Garden":
        try:
            values.update({'Latin Name' : soup.findAll('h3', attrs = {'class' : 'product__h3-botanical-names'})[0].text.strip()})
        except:
            pass
        
    result.append(values)

# %%
reqs = requests.get('https://www.botanicalinterests.com/products/california-giants-zinnia-seeds')
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
imgs = soup.findAll('li', attrs = {'thumbnail-list__item slider__slide'})
for i in imgs:
    if 'w_' in i.find('img')['src']:                
        img_src = i.find('img')['src'].split('?')[0]

        response = requests.get('http:' + img_src)
        img = Image.open(io.BytesIO(response.content))
        tts = pytesseract.image_to_string(img)

        values.update({'Latin Name' : tts.split('\n')[2:3]})

info = soup.find('div', attrs = {'class' : 'tab-content'}).findAll('p')
for i in info:
    values.update({i.text.strip().split(': ')[0] : i.text.strip().split(': ')[1]})

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
result = []

a = plant_df.loc[~plant_df['link'].isna()]['plant_name']
b = plant_df.loc[~plant_df['link'].isna()]['seed_company']
c = plant_df.loc[~plant_df['link'].isna()]['link']

for x, y, z in zip(a, b, c):
    scrapping(x, y, z)

# %%
plant_df = pd.DataFrame.from_dict(result)

# %%
plant_df.loc[plant_df['seed_company'].str.contains("Botanical Interest")]
# Out:
#        plant_name        seed_company                       Latin Name  \
# 1       Artichoke  Botanical Interest                               []
# 4        Scallion  Botanical Interest                               []
# 10          Chive  Botanical Interest                         [Common]
# 22          Poppy  Botanical Interest                               []
# 23       Marigold  Botanical Interest                               []
# 24        Spinach  Botanical Interest              [Spinacia oleracea]
# 25          Basil  Botanical Interest                               []
# 26          Basil  Botanical Interest                               []
# 27        Parsley  Botanical Interest  [Eruca vesicaria subsp. sativa]
# 28          Basil  Botanical Interest               [Italian Genovese]
# 29       Marigold  Botanical Interest                               []
# 31            Pea  Botanical Interest                               []
# 33       Marigold  Botanical Interest                               []
# 34          Poppy  Botanical Interest                 [Papaver rhoeas]
# 39        Arugula  Botanical Interest  [Eruca vesicaria subsp. sativa]
# 43         Sorrel  Botanical Interest                  [Rumex acetosa]
# 44           Dill  Botanical Interest                               []
# 45           Dill  Botanical Interest                               []
# 46      Coriander  Botanical Interest                              NaN
# 47  Forget-Me-Not  Botanical Interest                               []
# 48         Cosmos  Botanical Interest                         [ANNUAL]
# 49          Shiso  Botanical Interest                               []
# 50         Borage  Botanical Interest             [Borago officinalis]
# 51     Moonflower  Botanical Interest                   [Ipomoea alba]
# 90           Mint  Botanical Interest                     [Mentha sp.]
#
#    Days to Maturity          Family  \
# 1      150–180 days      Asteraceae
# 4           65 days       Alliaceae
# 10              NaN       Alliaceae
# 22              NaN    Papaveraceae
# 23              NaN      Asteraceae
# 24       28–45 days   Amaranthaceae
# 25              NaN      Laminaceae
# 26              NaN      Laminaceae
# 27       20–45 days    Brassicaceae
# 28              NaN      Laminaceae
# 29              NaN      Asteraceae
# 31          60 days        Fabaceae
# 33              NaN      Asteraceae
# 34              NaN    Papaveraceae
# 39       20–45 days    Brassicaceae
# 43          60 days    Polygonaceae
# 44              NaN        Apiaceae
# 45              NaN        Apiaceae
# 46              NaN             NaN
# 47              NaN    Boraginaceae
# 48              NaN      Asteraceae
# 49              NaN       Lamiaceae
# 50              NaN    Boraginaceae
# 51              NaN  Convolvulaceae
# 90              NaN      Laminaceae
#
#                                                Native  \
# 1                                Mediterranean region
# 4                   Likely originated in eastern Asia
# 10                        Europe, Asia, North America
# 22                               Mediterranean region
# 23                           Mexico and South America
# 24                                     Southwest Asia
# 25                                            Unknown
# 26  Probably Africa, but in cultivation for so lon...
# 27   Africa, Asia, Europe; exact native range obscure
# 28  Probably Africa, but in cultivation for so lon...
# 29                           Mexico and South America
# 31             Western Asia, Europe, and North Africa
# 33                           Mexico and South America
# 34                           Europe, Asia, and Africa
# 39   Africa, Asia, Europe; exact native range obscure
# 43               Morocco, Europe, Asia, and Australia
# 44                                Probably South Asia
# 45                                Probably South Asia
# 46                                                NaN
# 47                                      Europe & Asia
# 48                                 Mexico and Arizona
# 49                                               Asia
# 50                      Africa, west Asia, and Europe
# 51                             Mexico, Southeast U.S.
# 90                                            Unknown
#
#                                             Hardiness  \
# 1         Frost-tolerant perennial in USDA zones 7-10
# 4   Allium fistulosum is perennial in USDA 6-9, al...
# 10                  Hardy perennial in USDA zones 4–8
# 22                                             Annual
# 23                                             Annual
# 24  Frost-tolerant annual. Very cold hardy; fall-s...
# 25                             Frost-sensitive annual
# 26                             Frost-sensitive annual
# 27                              Frost-tolerant annual
# 28                             Frost-sensitive annual
# 29                                             Annual
# 31                              Frost-tolerant annual
# 33                                             Annual
# 34                                             Annual
# 39                              Frost-tolerant annual
# 43                  Hardy perennial in USDA zones 3–7
# 44                              Frost-tolerant annual
# 45                              Frost-tolerant annual
# 46                                                NaN
# 47  M. sylvatica is a perennial (short lived) in U...
# 48                                             Annual
# 49  Usually grown as a frost-sensitive annual; per...
# 50                           Annual; re-seeds readily
# 51  Perennial in USDA zones 10 and warmer; otherwi...
# 90  Perennial in USDA zones 6 and warmer, and poss...
#
#                                      Plant Dimensions  \
# 1                                 5' tall, 4'–8' wide
# 4                                                 NaN
# 10                              12" tall, 8"–10" wide
# 22                          24"–36" tall, 9"–12" wide
# 23                                           18" tall
# 24                                         6"–8" tall
# 25                            Up to 24" tall and wide
# 26                              12"–24" tall and wide
# 27                           12"–24" tall at maturity
# 28                             18"–24" tall, 10" wide
# 29                                 24" tall, 12" wide
# 31                                           28" tall
# 33                                       24"–36" tall
# 34                              12"–14" tall and wide
# 39                           12"–24" tall at maturity
# 43                              18"–24" tall and wide
# 44                                       30"–36" tall
# 45                          30"–36" tall, bushy plant
# 46                                                NaN
# 47                                        6"–24" tall
# 48                         3'-6' " tall, 18"-36" wide
# 49                                           18" tall
# 50                           2'–3' tall, 12"–18" wide
# 51                                       10'–20' vine
# 90  18" tall and spreading indefinitely by undergr...
#
#                                          Variety Info  \
# 1   Dark green with slightly purple base. Heavy be...
# 4   16"–18" slender, white scallions with bluish-g...
# 10  Bright green, slender, hollow leaves with a mi...
# 22  3"–5" dark burgundy, semi-double flowers with ...
# 23                          2"–3" creamy white blooms
# 24   Rich green, glossy, 6" slightly puckered leaves.
# 25  This green-leaved, purplish-pink flowered tuls...
# 26  Upright, multi-branched, and quite bushy plant...
# 27  2"–6" soft, green leaves are deeply pinnately ...
# 28  Large, dark green almond-shaped leaves. This i...
# 29  3" bright yellow, fully double flowers with th...
# 31  4" long, stringless, crunchy pods; 2 per clust...
# 33  4" blooms in tangerine orange, rich gold, and ...
# 34  2"–3" vibrant red blooms sometimes with black ...
# 39  2"–6" soft, green leaves are deeply pinnately ...
# 43  Green, crinkled, arrow-shaped leaves with lemo...
# 44  Bouquet' has 6" flower heads with several umbe...
# 45  Tetra' has fern-like, softly delicate, dark gr...
# 46                                                NaN
# 47  Numerous ⅓" across, petite blue star-shaped fl...
# 48  3"–4" wide flowers in white, pink, rose, and c...
# 49  Either green, widely toothed leaves, or mulber...
# 50                                                NaN
# 51              5"–6", trumpet-shaped, white flowers.
# 90  This common mint is neither peppermint, spearm...
#
#                                   When to Sow Outside  ... DIRECT SEEDING:  \
# 1                                       Cold Climates  ...             NaN
# 4   4 to 6 weeks before your average last frost da...  ...             NaN
# 10  4 to 6 weeks before your average last frost da...  ...             NaN
# 22  RECOMMENDED. 4 to 6 weeks before your average ...  ...             NaN
# 23  1 to 2 weeks after your average last frost dat...  ...             NaN
# 24  RECOMMENDED. 4 to 6 weeks before your average ...  ...             NaN
# 25  1 to 2 weeks after your average last frost dat...  ...             NaN
# 26  1 to 2 weeks after your average last frost dat...  ...             NaN
# 27  RECOMMENDED. 2 to 4 weeks before your average ...  ...             NaN
# 28  1 to 2 weeks after your average last frost dat...  ...             NaN
# 29  1 to 2 weeks after your average last frost dat...  ...             NaN
# 31  RECOMMENDED. 4 to 6 weeks before your average ...  ...             NaN
# 33  1 to 2 weeks after your average last frost dat...  ...             NaN
# 34  RECOMMENDED. 4 to 6 weeks before your average ...  ...             NaN
# 39  RECOMMENDED. 2 to 4 weeks before your average ...  ...             NaN
# 43  RECOMMENDED. 1 to 2 weeks before your average ...  ...             NaN
# 44  RECOMMENDED. 1 to 2 weeks before your average ...  ...             NaN
# 45  RECOMMENDED. 1 to 2 weeks before your average ...  ...             NaN
# 46                                                NaN  ...             NaN
# 47  RECOMMENDED. 1 to 2 weeks before average last ...  ...             NaN
# 48  RECOMMENDED. 1 to 2 weeks after your average l...  ...             NaN
# 49  RECOMMENDED. 1 to 2 weeks after your average l...  ...             NaN
# 50  RECOMMENDED. 1 to 2 weeks before your average ...  ...             NaN
# 51  RECOMMENDED. 1 to 2 weeks after your average l...  ...             NaN
# 90  1 to 2 weeks after your average last frost dat...  ...             NaN
#
#    AVG. DIRECT SEEDING RATE: INSECT PESTS: DISEASE: POST HARVEST: NOTE:  \
# 1                        NaN           NaN      NaN           NaN   NaN
# 4                        NaN           NaN      NaN           NaN   NaN
# 10                       NaN           NaN      NaN           NaN   NaN
# 22                       NaN           NaN      NaN           NaN   NaN
# 23                       NaN           NaN      NaN           NaN   NaN
# 24                       NaN           NaN      NaN           NaN   NaN
# 25                       NaN           NaN      NaN           NaN   NaN
# 26                       NaN           NaN      NaN           NaN   NaN
# 27                       NaN           NaN      NaN           NaN   NaN
# 28                       NaN           NaN      NaN           NaN   NaN
# 29                       NaN           NaN      NaN           NaN   NaN
# 31                       NaN           NaN      NaN           NaN   NaN
# 33                       NaN           NaN      NaN           NaN   NaN
# 34                       NaN           NaN      NaN           NaN   NaN
# 39                       NaN           NaN      NaN           NaN   NaN
# 43                       NaN           NaN      NaN           NaN   NaN
# 44                       NaN           NaN      NaN           NaN   NaN
# 45                       NaN           NaN      NaN           NaN   NaN
# 46                       NaN           NaN      NaN           NaN   NaN
# 47                       NaN           NaN      NaN           NaN   NaN
# 48                       NaN           NaN      NaN           NaN   NaN
# 49                       NaN           NaN      NaN           NaN   NaN
# 50                       NaN           NaN      NaN           NaN   NaN
# 51                       NaN           NaN      NaN           NaN   NaN
# 90                       NaN           NaN      NaN           NaN   NaN
#
#    Direct seed: DISEASES: PELLETED SEED: Direct seeding is not recommended.
# 1           NaN       NaN            NaN                                NaN
# 4           NaN       NaN            NaN                                NaN
# 10          NaN       NaN            NaN                                NaN
# 22          NaN       NaN            NaN                                NaN
# 23          NaN       NaN            NaN                                NaN
# 24          NaN       NaN            NaN                                NaN
# 25          NaN       NaN            NaN                                NaN
# 26          NaN       NaN            NaN                                NaN
# 27          NaN       NaN            NaN                                NaN
# 28          NaN       NaN            NaN                                NaN
# 29          NaN       NaN            NaN                                NaN
# 31          NaN       NaN            NaN                                NaN
# 33          NaN       NaN            NaN                                NaN
# 34          NaN       NaN            NaN                                NaN
# 39          NaN       NaN            NaN                                NaN
# 43          NaN       NaN            NaN                                NaN
# 44          NaN       NaN            NaN                                NaN
# 45          NaN       NaN            NaN                                NaN
# 46          NaN       NaN            NaN                                NaN
# 47          NaN       NaN            NaN                                NaN
# 48          NaN       NaN            NaN                                NaN
# 49          NaN       NaN            NaN                                NaN
# 50          NaN       NaN            NaN                                NaN
# 51          NaN       NaN            NaN                                NaN
# 90          NaN       NaN            NaN                                NaN
#
# [25 rows x 67 columns]

# %%
plant_df.loc[plant_df['']]
# Out:
#         plant_name        seed_company                        Latin Name  \
# 0          Cardoon         Baker Creek  Cynara cardunculus var. scolymus
# 1        Artichoke  Botanical Interest                                []
# 2           Celery         Baker Creek                  Apium graveolens
# 3   Butterfly Bush         Baker Creek                    June Favorites
# 4         Scallion  Botanical Interest                                []
# ..             ...                 ...                               ...
# 88    Alpine Aster  Swallowtail Garden                     Aster alpinus
# 89        Lavender       Johnny's Seed            Lavandula angustifolia
# 90            Mint  Botanical Interest                      [Mentha sp.]
# 91           Shiso       Johnny's Seed                Perilla frutescens
# 92    Anise Hyssop       Johnny's Seed              Agastache foeniculum
#
#    Days to Maturity      Family                             Native  \
# 0               NaN         NaN                                NaN
# 1      150–180 days  Asteraceae               Mediterranean region
# 2               NaN         NaN                                NaN
# 3               NaN         NaN                                NaN
# 4           65 days   Alliaceae  Likely originated in eastern Asia
# ..              ...         ...                                ...
# 88              NaN         NaN                                NaN
# 89              NaN         NaN                                NaN
# 90              NaN  Laminaceae                            Unknown
# 91              NaN         NaN                                NaN
# 92              NaN         NaN                                NaN
#
#                                             Hardiness  \
# 0                                                 NaN
# 1         Frost-tolerant perennial in USDA zones 7-10
# 2                                                 NaN
# 3                                                 NaN
# 4   Allium fistulosum is perennial in USDA 6-9, al...
# ..                                                ...
# 88                                                NaN
# 89                                                NaN
# 90  Perennial in USDA zones 6 and warmer, and poss...
# 91                                                NaN
# 92                                                NaN
#
#                                      Plant Dimensions  \
# 0                                                 NaN
# 1                                 5' tall, 4'–8' wide
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 88                                                NaN
# 89                                                NaN
# 90  18" tall and spreading indefinitely by undergr...
# 91                                                NaN
# 92                                                NaN
#
#                                          Variety Info  \
# 0                                                 NaN
# 1   Dark green with slightly purple base. Heavy be...
# 2                                                 NaN
# 3                                                 NaN
# 4   16"–18" slender, white scallions with bluish-g...
# ..                                                ...
# 88                                                NaN
# 89                                                NaN
# 90  This common mint is neither peppermint, spearm...
# 91                                                NaN
# 92                                                NaN
#
#                                   When to Sow Outside  ... DIRECT SEEDING:  \
# 0                                                 NaN  ...             NaN
# 1                                       Cold Climates  ...             NaN
# 2                                                 NaN  ...             NaN
# 3                                                 NaN  ...             NaN
# 4   4 to 6 weeks before your average last frost da...  ...             NaN
# ..                                                ...  ...             ...
# 88                                                NaN  ...             NaN
# 89                                                NaN  ...             NaN
# 90  1 to 2 weeks after your average last frost dat...  ...             NaN
# 91                                                NaN  ...             NaN
# 92                                                NaN  ...             NaN
#
#    AVG. DIRECT SEEDING RATE: INSECT PESTS: DISEASE: POST HARVEST: NOTE:  \
# 0                        NaN           NaN      NaN           NaN   NaN
# 1                        NaN           NaN      NaN           NaN   NaN
# 2                        NaN           NaN      NaN           NaN   NaN
# 3                        NaN           NaN      NaN           NaN   NaN
# 4                        NaN           NaN      NaN           NaN   NaN
# ..                       ...           ...      ...           ...   ...
# 88                       NaN           NaN      NaN           NaN   NaN
# 89                       NaN           NaN      NaN           NaN   NaN
# 90                       NaN           NaN      NaN           NaN   NaN
# 91                       NaN           NaN      NaN           NaN   NaN
# 92                       NaN           NaN      NaN           NaN   NaN
#
#    Direct seed: DISEASES: PELLETED SEED: Direct seeding is not recommended.
# 0           NaN       NaN            NaN                                NaN
# 1           NaN       NaN            NaN                                NaN
# 2           NaN       NaN            NaN                                NaN
# 3           NaN       NaN            NaN                                NaN
# 4           NaN       NaN            NaN                                NaN
# ..          ...       ...            ...                                ...
# 88          NaN       NaN            NaN                                NaN
# 89          NaN       NaN            NaN
# 90          NaN       NaN            NaN                                NaN
# 91          NaN       NaN            NaN                                NaN
# 92          NaN       NaN            NaN                                NaN
#
# [93 rows x 67 columns]

# %%
result = []
for i in df['Latin Name'].str.split():
    search_kw = '+'.join(i[0:1+1])
    
    url = f'https://plants.ces.ncsu.edu/find_a_plant/?q={search_kw}'
    reqs = requests.get(url)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    
    values = {}
    for n in soup.find('div', attrs = {'id' : 'plant_list'}).findAll('h2'):
        
        key = n.find('a')['href']
        
        if n.find(i[-1]) != -1:
            url = f'https://plants.ces.ncsu.edu{key}'
            reqs = requests.get(url)
            soup = BeautifulSoup(reqs.text, 'html.parser')

            for dd in soup.find('div', attrs = 'bricks').findAll("dd"):
                values.update({'name' : soup.find('div', attrs = {'id' : 'plant_detail'}).find('h1').text.strip()})
                values.update({dd.find_previous_sibling(name = 'dt').text.strip() : dd.text.strip()})
    result.append(values)

ref = pd.DataFrame.from_dict(result)

# %%
def scrapping(plant, company, link):
    
    reqs = requests.get(link)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    
    values = {}
    values.update({'plant_name' : plant,
                   'seed_company' : company})

    if company == "Johnny's Seed":
        try:   
            info = soup.findAll("dd", attrs = {'class' : "c-facts__definition"})
            for i in info:
                values.update({i.find_previous_sibling(name = 'dt').find('h3').text.strip() : i.text.strip()})

            detail = soup.find('div', attrs = {'id' : 'tabpanel_2-1'}).findAll('span', attrs = {'style' : ''})
            for i in detail:
                values.update({i.find_previous_sibling(name = 'span').text.strip() : i.text.strip()})
            
        except:
            pass
            
    elif company == "Baker Creek":
        try:
            values.update({'Latin Name' : soup.find('div', attrs = {'class' : 'value'}).findAll('li')[-1].text.strip()})
        
        except:
            pass
        
    elif company == "Botanical Interest":
        
        try:
            imgs = soup.findAll('li', attrs = {'thumbnail-list__item slider__slide'})
            info = soup.find('div', attrs = {'class' : 'tab-content'}).findAll('p')

            for x in imgs:
                if 'w_' in x.find('img')['src']:                
                    img_src = x.find('img')['src'].split('?')[0]

                    response = requests.get('http:' + img_src)
                    img = Image.open(io.BytesIO(response.content))
                    tts = pytesseract.image_to_string(img)

            for x in info:
                values.update({x.text.strip().split(': ')[0] : x.text.strip().split(': ')[1]})
        
        except:
            pass
            
    elif company == "Swallowtail Garden":

        try:
            values.update({'Latin_name' : soup.find('h3', attrs = {'class' : 'product__h3-botanical-names'}).text.strip()})
            
        except:
            pass
        
    result.append(values)
