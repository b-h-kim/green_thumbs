# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup, NavigableString, Tag

# %% [markdown]
# ## Import existing  Excel-file

# %%
# import existing excel file
plant_detail_df = pd.read_excel('../data/Garden_Plant.xlsx')

# %%
# set the header
plant_detail_df.columns = plant_detail_df.iloc[0]
plant_detail_df = plant_detail_df[1:]

# %%
# drop rows with no value
plant_detail_df = plant_detail_df.loc[~plant_detail_df['Name'].isna()]

# %%
plant_df = pd.DataFrame()

# %%
# split the name column to name and variety
plant_df[['plant_name', 'plant_variety']] = plant_detail_df['Name'].str.split(r'\n', expand = True)

# %%
plant_detail_df.loc[plant_detail_df['Latin'].str.split(' ').str.len() > 2]
# Out:
# 0                                Name  \
# 2            Cardoon\nGobbo Di Nizzia
# 8              Oregano\nGreek Oregano
# 41          Celosia\nFlamingo Feather
# 42                  Arugula\nRoquette
# 50     Forget-Me-Not\nSpring & Summer
# 61  Grass\nKorean Fea­ther Reed Grass
# 64           Columbine \nBlack Barlow
# 65       Columbine \nBor­deaux Barlow
# 66            Columbine \nDwarf White
# 67        Coral Bells\nNewest Hybrids
# 71               Komatsuna\nOld Tokyo
# 76                 Sedum \nRed Carpet
# 82                   Gai Lan\nYod Fah
# 87             Bok Choy\nPurple Lady
# 90                  Kale\nRussian Red
#
# 0                                         Latin Origin    Type Year  \
# 2              Cynara cardunculus var. scolymus     IT    Tall   22
# 8                       Origanum vulgare hirtum    NaN    Herb   23
# 41                     Celosia argentea spicata    NaN  Flower   22
# 42                Eruca vesicaria subsp. Sativa    NaN     NaN   22
# ...

# %%
plant_df[['genus', 'species', 'subsp/var']] = plant_detail_df['Latin'].str.split(n = 2, expand = True)

# %%
plant_df.loc[~plant_df['subsp/var'].isna()]
# Out:
#        plant_name               plant_variety          genus      species  \
# 2         Cardoon             Gobbo Di Nizzia         Cynara  cardunculus
# 8         Oregano               Greek Oregano       Origanum      vulgare
# 41        Celosia            Flamingo Feather        Celosia     argentea
# 42        Arugula                    Roquette          Eruca    vesicaria
# 50  Forget-Me-Not             Spring & Summer       Myosotis    sylvatica
# 61          Grass  Korean Fea­ther Reed Grass  Calamagrostis  arundinacea
# 64     Columbine                 Black Barlow      Aquilegia     vulgaris
# 65     Columbine             Bor­deaux Barlow      Aquilegia     vulgaris
# 66     Columbine                  Dwarf White      Aquilegia   flabellata
# 67    Coral Bells              Newest Hybrids       Heuchera    americana
# 71      Komatsuna                   Old Tokyo       Brassica         rapa
# 76         Sedum                   Red Carpet          Sedum      spurium
# ...

# %%
# copy additional columns
plant_df['seed_company'] = plant_detail_df['Company'].str.replace('\n', ' ')
plant_df['link'] = plant_detail_df['Link']

# %%
plant_df.reset_index(drop = True, inplace = True)

# %%
plant_df
# Out:
#         plant_name         plant_variety      genus       species  \
# 0          Cardoon       Gobbo Di Nizzia     Cynara   cardunculus
# 1        Artichoke  Green Globe Improved     Cynara      scolymus
# 2           Celery   Chinese Pink Celery      Apium    graveolens
# 3   Butterfly Bush           Hybrids Mix   Buddleia       dividii
# 4         Scallion      Tokyo Long White     Allium    fistulosum
# ..             ...                   ...        ...           ...
# 91        Lavender      Ellagance Purple  Lavandula  angustifolia
# 92            Mint           Common Mint     Mentha           sp.
# 93           Shiso             Red Shiso    Perilla    frutescens
# 94    Anise Hyssop                  None  Agastache    foeniculum
# 95           Basil              Cardinal     Ocimum     basilicum
#
#         subsp/var        seed_company  \
# 0   var. scolymus         Baker Creek
# 1            None  Botanical Interest
# 2            None         Baker Creek
# ...

# %% [markdown]
# #### Create Company DF

# %%
seed_company = pd.DataFrame(columns = ['seed_company', 'url'])

# %%
seed_company['seed_company'] = plant_df['seed_company'].unique()

# %%
seed_company['url'][0] = 'https://www.rareseeds.com/catalogsearch/result/?q={search_kw}'
seed_company['url'][1] = 'https://www.botanicalinterests.com/search?q={search_kw}&options%5Bprefix%5D=last'
seed_company['url'][2] = 'https://www.johnnyseeds.com/search/?q={search_kw}&search-button=&lang=en_US'
seed_company['url'][3] = 'https://www.swallowtailgardenseeds.com'

# %%
seed_company

# %% [markdown]
# ## Johnny's Seed

# %% [markdown]
# #### use link from the df if available

# %%
plant_df
# Out:
#         plant_name         plant_variety      genus       species  \
# 0          Cardoon       Gobbo Di Nizzia     Cynara   cardunculus
# 1        Artichoke  Green Globe Improved     Cynara      scolymus
# 2           Celery   Chinese Pink Celery      Apium    graveolens
# 3   Butterfly Bush           Hybrids Mix   Buddleia       dividii
# 4         Scallion      Tokyo Long White     Allium    fistulosum
# ..             ...                   ...        ...           ...
# 91        Lavender      Ellagance Purple  Lavandula  angustifolia
# 92            Mint           Common Mint     Mentha           sp.
# 93           Shiso             Red Shiso    Perilla    frutescens
# 94    Anise Hyssop                  None  Agastache    foeniculum
# 95           Basil              Cardinal     Ocimum     basilicum
#
#         subsp/var        seed_company  \
# 0   var. scolymus         Baker Creek
# 1            None  Botanical Interest
# 2            None         Baker Creek
# ...

# %%
def j_search(g, s, subsp)

# %%
def scrapping(company, link):
    
    reqs = requests.get(link)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    
    result = []
    values = {}
    
    if company == "Johnny's Seed":
        
        # basic info
        info = soup.findAll("dd", attrs = {'class' : "c-facts__definition"})
        for i in info:
            values.update({i.find_previous_sibling(name = 'dt').find('h3').text.strip() : i.text.strip()})

        # detailed info
        detail = soup.find('div', attrs = {'class' : 'c-accordion__body s-lgc-pdp-content js-accordion__body'})\
                        .findAll('span', attrs = {'style' : ''})
        for d in detail:
            values.update(
                {'seed_company' : company,
                 'link' : link}
            )
            values.update(
                {d.find_previous_sibling(name = 'span', attrs = {'style':'font-weight: bold;'}).text.strip():d.text.strip()})
            
    elif company == "Baker Creek"
    
        values.update({'Latin Name' : soup.find('div', attrs = {'class' : 'value'}).find('em').text.strip()})
    
    elif company == "Botanical Interest"

# %%
pip install pyTesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import pyTesseract
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14536\1818808826.py in <module>
#       1 from PIL import Image
# ----> 2 import pyTesseract
#
# ModuleNotFoundError: No module named 'pyTesseract'

# %%
<div class="product__media media media--transparent">
      <img src="//cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=1946" alt="" srcset="//cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=246 246w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=493 493w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=600 600w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=713 713w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=823 823w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=990 990w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=1100 1100w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=1206 1206w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=1346 1346w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=1426 1426w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=1646 1646w, //cdn.shopify.com/s/files/1/0658/5693/0045/products/3393w_Lettuce-Romaine-Vivian-ORG.jpg?v=1683739094&amp;width=1946 1946w" width="1946" height="1946" loading="lazy" class="image-magnify-hover" sizes="(min-width: 1300px) 540px, (min-width: 990px) calc(45.0vw - 10rem), (min-width: 750px) calc((100vw - 11.5rem) / 2), calc(100vw / 1 - 4rem)">
    </div>

# %%
reqs = requests.get('https://www.rareseeds.com/zinnia-queen-lime')
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
soup.find('div', attrs = {'class' : 'value'}).find('em').text.strip()
# Out:
# 'Zinnia elegans'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# product: http://ogp.me/ns/product#">
# <script>
#     var BASE_URL = 'https\u003A\u002F\u002Fwww.rareseeds.com\u002F';
#     var require = {
#         'baseUrl': 'https\u003A\u002F\u002Fwww.rareseeds.com\u002Fstatic\u002Fversion1686046046\u002Ffrontend\u002FSmartwave\u002Fporto_customize\u002Fen_US'
# ...

# %%
# list of seed from Johnny's Seed
b_lst = plant_df\
    .loc[plant_df['seed_company'] == "Baker Creek"]\
    .loc[~plant_df['link'].isna()]\
    .index

for n in b_lst:
    # scrapping nth element
    reqs = requests.get(plant_df['link'][n])
    soup = BeautifulSoup(reqs.text, 'html.parser')
    
    if reqs.status_code == 400:
        # create empty dictionary
        values.update({'Latin Name' : soup.find('div', attrs = {'class' : 'product attribute overview'}).findAll('li')[-1].text.strip()})
    
    values.update({'name' : plant_df['plant_f_name'][n]})
    result.append(values)

# %%
result = []

for i in range(0, len(plant_df)-1):
    if plant_df['seed_company'][i] == "Johnny's Seed"
        
        reqs = requests.get(plant_df['link'][i])
        soup = BeautifulSoup(reqs.text, 'html.parser')
        
    elif plant_df['seed_company'][i] == "Baker Creek"
    
    elif plant_df['seed_company'][i] == "Botanical Interest"

# %%
result = []

# list of seed from Johnny's Seed
j_lst = plant_df\
    .loc[plant_df['seed_company'] == "Johnny's Seed"]\
    .loc[~plant_df['link'].isna()]\
    .index

for n in j_lst:
    # scrapping nth element
    reqs = requests.get(plant_df['link'][n])
    soup = BeautifulSoup(reqs.text, 'html.parser')

    # create empty dictionary
    values = {}
    
    # list of info
    info = soup.findAll("dd", attrs = {'class' : "c-facts__definition"})
    for i in info:
        values.update({i.find_previous_sibling(name = 'dt').find('h3').text.strip() : i.text.strip()})
    
    # list of detailed info
    detail = soup.find('div', attrs = {'class' : 'c-accordion__body s-lgc-pdp-content js-accordion__body'}).findAll('span', attrs = {'style' : ''})
    for d in detail:
        values.update({'f_name' : })
        values.update({d.find_previous_sibling(name = 'span', attrs = {'style' : 'font-weight: bold;'}).text.strip() : d.text.strip()})
        
    values.update({'name' : plant_df['plant_f_name'][n]})
    result.append(values)

# %%
df = pd.DataFrame.from_dict(result)

# %% [markdown]
# ## Baker's

# %%
# list of seed from Johnny's Seed
b_lst = plant_df\
    .loc[plant_df['seed_company'] == "Baker Creek"]\
    .loc[~plant_df['link'].isna()]\
    .index

for n in b_lst:
    # scrapping nth element
    reqs = requests.get(plant_df['link'][n])
    soup = BeautifulSoup(reqs.text, 'html.parser')
    
    if reqs.status_code == 400:
        # create empty dictionary
        values.update({'Latin Name' : soup.find('div', attrs = {'class' : 'product attribute overview'}).findAll('li')[-1].text.strip()})
    
    values.update({'name' : plant_df['plant_f_name'][n]})
    result.append(values)

# %%
result

# %% [markdown]
# ## ncsu.edu database

# %%
result = []
for i in df['Latin Name'].str.split():
    search_kw = '+'.join(i[0:1+1])
    
    url = f'https://plants.ces.ncsu.edu/find_a_plant/?q={search_kw}'
    reqs = requests.get(url)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    
    values = {}
    for n in soup.find('div', attrs = {'id' : 'plant_list'}).findAll('h2'):
        
        key = n.find('a')['href']
        
        if n.find(i[-1]) != -1:
            url = f'https://plants.ces.ncsu.edu{key}'
            reqs = requests.get(url)
            soup = BeautifulSoup(reqs.text, 'html.parser')

            for dd in soup.find('div', attrs = 'bricks').findAll("dd"):
                values.update({'name' : soup.find('div', attrs = {'id' : 'plant_detail'}).find('h1').text.strip()})
                values.update({dd.find_previous_sibling(name = 'dt').text.strip() : dd.text.strip()})
    result.append(values)

ref = pd.DataFrame.from_dict(result)

# %%
ref

# %%
url = f'https://plants.ces.ncsu.edu/plants/{search_kw}/'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
values = []
for dd in soup.find('div', attrs = 'bricks').findAll("dd"):
    values.append(dd.find_previous_sibling(name = 'dt').text.strip() + (dd.text.strip()))
    
attrs = pd.DataFrame(values)

attrs = attrs[0].str.split(':', expand = True)
attrs.rename(columns = {0 : 'key', 1 : 'value'}, inplace = True)
attrs = attrs[['key', 'value']]

# %%
attrs

# %%
soup.find('p', attrs={'id' : 'collapsible-details-1'})

# %%
table = soup.find_all('span ', attr = {'class' : 'group_name'})
df = pd.read_html(str(table))[0]
